# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '20000',
#  '24H_fluctate_rate': '0.52',
#  'average_price': '3812126.0941',
#  'buy_price': '3811000',
#  'closing_price': '3813000',
#  'date': '1548871029738',
#  'max_price': '3849000',
#  'min_price': '3769000',
#  'opening_price': '3793000',
#  'sell_price': '3813000',
#  'units_traded': '3519.33517474',
#  'volume_1day': '3519.33517474',
#  'volume_7day': '20933.20928813'}

# %%
# 아래에 코드를 작성하세요.
gap = int(btc['opening_price'])+(int(btc['max_price'])-int(btc['min_price']))
if gap > int(btc['max_price']):
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '2.1',
#          '24H_fluctate_rate': '2.88',
#          'average_price': '76.6765',
#          'buy_price': '73.7',
#          'closing_price': '74.8',
#          'max_price': '82.1',
#          'min_price': '69.5',
#          'opening_price': '72.7',
#          'sell_price': '74.8',
#          'units_traded': '1405088.52956291',
#          'volume_1day': '1405088.52956291',
#          'volume_7day': '3892075.877406401802907228'},
#  'ADA': {'24H_fluctate': '0.6',
#          '24H_fluctate_rate': '1.40',
#          'average_price': '42.9061',
#          'buy_price': '43.4',
#          'closing_price': '43.4',
#          'max_price': '44',
#          'min_price': '41.5',
#          'opening_price': '42.8',
#          'sell_price': '43.6',
#          'units_traded': '15107316.43205708',
#          'volume_1day': '15107316.43205708',
#          'volume_7day': '57420193.97373059'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-11',
#         '24H_fluctate_rate': '-2.60',
#         'average_price': '413.9603',
#         'buy_price': '411',
#         'closing_price': '412',
#         'max_price': '424',
#         'min_price': '408',
#         'opening_price': '423',
#         'sell_price': '412',
#         'units_traded': '411335.84045628',
#         'volume_1day': '411335.84045628',
#         'volume_7day': '4223239.585352049422715745'},
#  'AMO': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '1.49',
#          'average_price': '0.6787',
#          'buy_price': '0.67',
#          'closing_price': '0.68',
#          'max_price': '0.71',
#          'min_price': '0.64',
#          'opening_price': '0.67',
#          'sell_price': '0.68',
#          'units_traded': '248526183.8407',
#          'volume_1day': '248526183.8407',
#          'volume_7day': '1770089479.809176443435811961'},
#  'APIS': {'24H_fluctate': '-0.02',
#           '24H_fluctate_rate': '-0.93',
#           'average_price': '2.0821',
#           'buy_price': '2.06',
#           'closing_price': '2.11',
#           'max_price': '2.14',
#           'min_price': '2.01',
#           'opening_price': '2.13',
#           'sell_price': '2.1',
#           'units_traded': '105249054.44176291',
#           'volume_1day': '105249054.44176291',
#           'volume_7day': '29520686613.051418710995191812'},
#  'ARN': {'24H_fluctate': '11',
#          '24H_fluctate_rate': '3.87',
#          'average_price': '300.7693',
#          'buy_price': '293',
#          'closing_price': '295',
#          'max_price': '330',
#          'min_price': '279',
#          'opening_price': '284',
#          'sell_price': '298',
#          'units_traded': '618899.95331574',
#          'volume_1day': '618899.95331574',
#          'volume_7day': '1608000.5835867'},
#  'BAT': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '2.40',
#          'average_price': '127.0796',
#          'buy_price': '125',
#          'closing_price': '128',
#          'max_price': '130',
#          'min_price': '123',
#          'opening_price': '125',
#          'sell_price': '129',
#          'units_traded': '289053.8707',
#          'volume_1day': '289053.8707',
#          'volume_7day': '1959372.888630454015487282'},
#  'BCD': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '0.25',
#          'average_price': '793.4812',
#          'buy_price': '786',
#          'closing_price': '799',
#          'max_price': '815',
#          'min_price': '776',
#          'opening_price': '797',
#          'sell_price': '813',
#          'units_traded': '48804.78313582',
#          'volume_1day': '48804.78313582',
#          'volume_7day': '265620.51884852'},
#  'BCH': {'24H_fluctate': '7000',
#          '24H_fluctate_rate': '5.70',
#          'average_price': '125657.9505',
#          'buy_price': '129500',
#          'closing_price': '129600',
#          'max_price': '133400',
#          'min_price': '119700',
#          'opening_price': '122600',
#          'sell_price': '129800',
#          'units_traded': '29469.16544372',
#          'volume_1day': '29469.16544372',
#          'volume_7day': '154136.54939076'},
#  'BHPC': {'24H_fluctate': '14',
#           '24H_fluctate_rate': '1.86',
#           'average_price': '797.2691',
#           'buy_price': '765',
#           'closing_price': '766',
#           'max_price': '848',
#           'min_price': '747',
#           'opening_price': '752',
#           'sell_price': '772',
#           'units_traded': '490104.5171222',
#           'volume_1day': '490104.5171222',
#           'volume_7day': '1640328.117864747943599513'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '2150',
#          '24H_fluctate_rate': '3.01',
#          'average_price': '72042.4426',
#          'buy_price': '73300',
#          'closing_price': '73400',
#          'max_price': '75300',
#          'min_price': '69450',
#          'opening_price': '71250',
#          'sell_price': '73500',
#          'units_traded': '19303.52528623',
#          'volume_1day': '19303.52528623',
#          'volume_7day': '87880.67392531'},
#  'BTC': {'24H_fluctate': '20000',
#          '24H_fluctate_rate': '0.52',
#          'average_price': '3812130.1359',
#          'buy_price': '3811000',
#          'closing_price': '3813000',
#          'max_price': '3849000',
#          'min_price': '3769000',
#          'opening_price': '3793000',
#          'sell_price': '3813000',
#          'units_traded': '3520.34897474',
#          'volume_1day': '3520.34897474',
#          'volume_7day': '20933.20928813'},
#  'BTG': {'24H_fluctate': '590',
#          '24H_fluctate_rate': '5.46',
#          'average_price': '11012.5829',
#          'buy_price': '11400',
#          'closing_price': '11390',
#          'max_price': '12200',
#          'min_price': '10570',
#          'opening_price': '10800',
#          'sell_price': '11470',
#          'units_traded': '23307034.17708645',
#          'volume_1day': '23307034.17708645',
#          'volume_7day': '141291923.67037591'},
#  'BZNT': {'24H_fluctate': '0.2',
#           '24H_fluctate_rate': '0.72',
#           'average_price': '27.6489',
#           'buy_price': '27.8',
#           'closing_price': '27.9',
#           'max_price': '28.3',
#           'min_price': '27',
#           'opening_price': '27.7',
#           'sell_price': '27.9',
#           'units_traded': '5408485.84622307',
#           'volume_1day': '5408485.84622307',
#           'volume_7day': '47658704.189921087316617119'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-0.09',
#          '24H_fluctate_rate': '-0.38',
#          'average_price': '25.7698',
#          'buy_price': '25.8',
#          'closing_price': '25.8',
#          'max_price': '26.2',
#          'min_price': '25.1',
#          'opening_price': '25.9',
#          'sell_price': '25.9',
#          'units_traded': '6302732.6308',
#          'volume_1day': '6302732.6308',
#          'volume_7day': '39676040.022873846194089127'},
#  'CTXC': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '109.4649',
#           'buy_price': '109',
#           'closing_price': '109',
#           'max_price': '112',
#           'min_price': '108',
#           'opening_price': '109',
#           'sell_price': '110',
#           'units_traded': '235223.63720901',
#           'volume_1day': '235223.63720901',
#           'volume_7day': '10879729.042950033423884397'},
#  'DASH': {'24H_fluctate': '300',
#           '24H_fluctate_rate': '0.40',
#           'average_price': '74903.1385',
#           'buy_price': '75300',
#           'closing_price': '75300',
#           'max_price': '76700',
#           'min_price': '73500',
#           'opening_price': '75000',
#           'sell_price': '75600',
#           'units_traded': '5413282.30916927',
#           'volume_1day': '5413282.30916927',
#           'volume_7day': '36999309.94564957'},
#  'ELF': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.87',
#          'average_price': '114.1381',
#          'buy_price': '114',
#          'closing_price': '113',
#          'max_price': '116',
#          'min_price': '112',
#          'opening_price': '114',
#          'sell_price': '115',
#          'units_traded': '1090842.65299825',
#          'volume_1day': '1090842.65299825',
#          'volume_7day': '16887394.217161301499293148'},
#  'ENJ': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '34.6327',
#          'buy_price': '34.2',
#          'closing_price': '34.8',
#          'max_price': '35.8',
#          'min_price': '34',
#          'opening_price': '34.8',
#          'sell_price': '35',
#          'units_traded': '896939.61861381',
#          'volume_1day': '896939.61861381',
#          'volume_7day': '6917875.895764816502471234'},
#  'EOS': {'24H_fluctate': '41',
#          '24H_fluctate_rate': '1.62',
#          'average_price': '2536.5255',
#          'buy_price': '2558',
#          'closing_price': '2562',
#          'max_price': '2595',
#          'min_price': '2476',
#          'opening_price': '2521',
#          'sell_price': '2562',
#          'units_traded': '1715740.19171015',
#          'volume_1day': '1715740.19171015',
#          'volume_7day': '9530883.22652267'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '46',
#          '24H_fluctate_rate': '1.05',
#          'average_price': '4344.539',
#          'buy_price': '4401',
#          'closing_price': '4401',
#          'max_price': '4442',
#          'min_price': '4278',
#          'opening_price': '4355',
#          'sell_price': '4410',
#          'units_traded': '33312.95449923',
#          'volume_1day': '33312.95449923',
#          'volume_7day': '266618.916899245828387177'},
#  'ETH': {'24H_fluctate': '2800',
#          '24H_fluctate_rate': '2.39',
#          'average_price': '118193.8247',
#          'buy_price': '119500',
#          'closing_price': '119500',
#          'max_price': '121000',
#          'min_price': '115200',
#          'opening_price': '116700',
#          'sell_price': '119700',
#          'units_traded': '96419.21346079',
#          'volume_1day': '96419.21346079',
#          'volume_7day': '456600.585583928883433204'},
#  'ETHOS': {'24H_fluctate': '-12',
#            '24H_fluctate_rate': '-6.77',
#            'average_price': '168.2708',
#            'buy_price': '165',
#            'closing_price': '165',
#            'max_price': '177',
#            'min_price': '163',
#            'opening_price': '177',
#            'sell_price': '167',
#            'units_traded': '3710045.60544693',
#            'volume_1day': '3710045.60544693',
#            'volume_7day': '26719506.60935208'},
#  'ETZ': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.22',
#          'average_price': '119.7297',
#          'buy_price': '120',
#          'closing_price': '120',
#          'max_price': '126',
#          'min_price': '114',
#          'opening_price': '124',
#          'sell_price': '121',
#          'units_traded': '2282903.48885876',
#          'volume_1day': '2282903.48885876',
#          'volume_7day': '25615925.871133218463799625'},
#  'GNT': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '0.47',
#          'average_price': '62.9955',
#          'buy_price': '63.3',
#          'closing_price': '63.3',
#          'max_price': '63.9',
#          'min_price': '62.1',
#          'opening_price': '63',
#          'sell_price': '63.8',
#          'units_traded': '543408.9372',
#          'volume_1day': '543408.9372',
#          'volume_7day': '7619280.874509271923646569'},
#  'GTO': {'24H_fluctate': '0.5',
#          '24H_fluctate_rate': '1.83',
#          'average_price': '27.7461',
#          'buy_price': '27.8',
#          'closing_price': '27.8',
#          'max_price': '28.6',
#          'min_price': '27.1',
#          'opening_price': '27.3',
#          'sell_price': '28',
#          'units_traded': '1788185.3870941',
#          'volume_1day': '1788185.3870941',
#          'volume_7day': '46640822.37070292'},
#  'HC': {'24H_fluctate': '6',
#         '24H_fluctate_rate': '0.58',
#         'average_price': '1034.3628',
#         'buy_price': '1028',
#         'closing_price': '1037',
#         'max_price': '1077',
#         'min_price': '1013',
#         'opening_price': '1031',
#         'sell_price': '1049',
#         'units_traded': '77265.37052666',
#         'volume_1day': '77265.37052666',
#         'volume_7day': '823749.04810984'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '2.26',
#          'average_price': '222.8954',
#          'buy_price': '224',
#          'closing_price': '226',
#          'max_price': '229',
#          'min_price': '218',
#          'opening_price': '221',
#          'sell_price': '227',
#          'units_traded': '836834.18086365',
#          'volume_1day': '836834.18086365',
#          'volume_7day': '2704863.396317552481561244'},
#  'INS': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '2.42',
#          'average_price': '300.7163',
#          'buy_price': '296',
#          'closing_price': '296',
#          'max_price': '312',
#          'min_price': '286',
#          'opening_price': '289',
#          'sell_price': '300',
#          'units_traded': '357488.08943754',
#          'volume_1day': '357488.08943754',
#          'volume_7day': '2501430.6526101837'},
#  'IOST': {'24H_fluctate': '-0.06',
#           '24H_fluctate_rate': '-0.92',
#           'average_price': '6.5018',
#           'buy_price': '6.38',
#           'closing_price': '6.45',
#           'max_price': '6.71',
#           'min_price': '6.3',
#           'opening_price': '6.51',
#           'sell_price': '6.45',
#           'units_traded': '22713539.86474069',
#           'volume_1day': '22713539.86474069',
#           'volume_7day': '140788835.970567182927730267'},
#  'ITC': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.81',
#          'average_price': '109.2747',
#          'buy_price': '108',
#          'closing_price': '108',
#          'max_price': '111',
#          'min_price': '107',
#          'opening_price': '110',
#          'sell_price': '110',
#          'units_traded': '470543.59579009',
#          'volume_1day': '470543.59579009',
#          'volume_7day': '2778517.219297334019830166'},
#  'KNC': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.51',
#          'average_price': '131.6435',
#          'buy_price': '131',
#          'closing_price': '134',
#          'max_price': '135',
#          'min_price': '128',
#          'opening_price': '132',
#          'sell_price': '134',
#          'units_traded': '308639.02335758',
#          'volume_1day': '308639.02335758',
#          'volume_7day': '4805210.281965960938415985'},
#  'LINK': {'24H_fluctate': '-29',
#           '24H_fluctate_rate': '-5.85',
#           'average_price': '484.773',
#           'buy_price': '466',
#           'closing_price': '466',
#           'max_price': '516',
#           'min_price': '460',
#           'opening_price': '495',
#           'sell_price': '471',
#           'units_traded': '1624808.12730219',
#           'volume_1day': '1624808.12730219',
#           'volume_7day': '7717335.784058904920955245'},
#  'LOOM': {'24H_fluctate': '1.2',
#           '24H_fluctate_rate': '2.77',
#           'average_price': '44.3462',
#           'buy_price': '44.4',
#           'closing_price': '44.4',
#           'max_price': '46.6',
#           'min_price': '42.8',
#           'opening_price': '43.2',
#           'sell_price': '45.4',
#           'units_traded': '368696.71437873',
#           'volume_1day': '368696.71437873',
#           'volume_7day': '5431397.262618369962029207'},
#  'LRC': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-2.39',
#          'average_price': '65.84',
#          'buy_price': '65.3',
#          'closing_price': '65.3',
#          'max_price': '67.9',
#          'min_price': '63.7',
#          'opening_price': '66.9',
#          'sell_price': '65.5',
#          'units_traded': '20662217.99775515',
#          'volume_1day': '20662217.99775515',
#          'volume_7day': '213284249.38588008215940897'},
#  'LTC': {'24H_fluctate': '600',
#          '24H_fluctate_rate': '1.74',
#          'average_price': '34676.3932',
#          'buy_price': '34860',
#          'closing_price': '34960',
#          'max_price': '35300',
#          'min_price': '33910',
#          'opening_price': '34360',
#          'sell_price': '34960',
#          'units_traded': '9043.45200227',
#          'volume_1day': '9043.45200227',
#          'volume_7day': '62368.06273543'},
#  'MCO': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '0.22',
#          'average_price': '2207.2243',
#          'buy_price': '2221',
#          'closing_price': '2222',
#          'max_price': '2230',
#          'min_price': '2155',
#          'opening_price': '2217',
#          'sell_price': '2233',
#          'units_traded': '15524.49958001',
#          'volume_1day': '15524.49958001',
#          'volume_7day': '93691.62761246'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-0.7',
#           '24H_fluctate_rate': '-1.56',
#           'average_price': '44.1021',
#           'buy_price': '43.9',
#           'closing_price': '44',
#           'max_price': '45.7',
#           'min_price': '43.2',
#           'opening_price': '44.7',
#           'sell_price': '44.3',
#           'units_traded': '10937456.14414286',
#           'volume_1day': '10937456.14414286',
#           'volume_7day': '57631584.777222934170642094'},
#  'MTL': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-1.14',
#          'average_price': '259.5567',
#          'buy_price': '257',
#          'closing_price': '259',
#          'max_price': '267',
#          'min_price': '255',
#          'opening_price': '262',
#          'sell_price': '261',
#          'units_traded': '236472.3607',
#          'volume_1day': '236472.3607',
#          'volume_7day': '5674941.69000183'},
#  'OCN': {'24H_fluctate': '-0.09',
#          '24H_fluctate_rate': '-3.64',
#          'average_price': '2.4046',
#          'buy_price': '2.38',
#          'closing_price': '2.38',
#          'max_price': '2.49',
#          'min_price': '2.33',
#          'opening_price': '2.47',
#          'sell_price': '2.39',
#          'units_traded': '84343696.93928858',
#          'volume_1day': '84343696.93928858',
#          'volume_7day': '394021947.550157397871036335'},
#  'OMG': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '0.65',
#          'average_price': '1240.5762',
#          'buy_price': '1239',
#          'closing_price': '1237',
#          'max_price': '1270',
#          'min_price': '1218',
#          'opening_price': '1229',
#          'sell_price': '1252',
#          'units_traded': '128113.36390433',
#          'volume_1day': '128113.36390433',
#          'volume_7day': '487248929.106080365978510604'},
#  'PAY': {'24H_fluctate': '-9',
#          '24H_fluctate_rate': '-3.05',
#          'average_price': '296.5098',
#          'buy_price': '286',
#          'closing_price': '286',
#          'max_price': '306',
#          'min_price': '282',
#          'opening_price': '295',
#          'sell_price': '289',
#          'units_traded': '3413552.68629019',
#          'volume_1day': '3413552.68629019',
#          'volume_7day': '40889949.63750952879709812'},
#  'PIVX': {'24H_fluctate': '-1',
#           '24H_fluctate_rate': '-0.13',
#           'average_price': '785.0334',
#           'buy_price': '760',
#           'closing_price': '758',
#           'max_price': '838',
#           'min_price': '752',
#           'opening_price': '759',
#           'sell_price': '769',
#           'units_traded': '373532.4715854',
#           'volume_1day': '373532.4715854',
#           'volume_7day': '3278346.88251444'},
#  'PLY': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.32',
#          'average_price': '29.9987',
#          'buy_price': '29.5',
#          'closing_price': '29.7',
#          'max_price': '31',
#          'min_price': '29',
#          'opening_price': '30.1',
#          'sell_price': '29.8',
#          'units_traded': '2399720.04029959',
#          'volume_1day': '2399720.04029959',
#          'volume_7day': '29657620.182250657'},
#  'POLY': {'24H_fluctate': '1',
#           '24H_fluctate_rate': '0.89',
#           'average_price': '111.3807',
#           'buy_price': '112',
#           'closing_price': '113',
#           'max_price': '115',
#           'min_price': '109',
#           'opening_price': '112',
#           'sell_price': '115',
#           'units_traded': '750624.2208087',
#           'volume_1day': '750624.2208087',
#           'volume_7day': '6058837.613484686092072978'},
#  'POWR': {'24H_fluctate': '3.5',
#           '24H_fluctate_rate': '3.95',
#           'average_price': '90.4927',
#           'buy_price': '91.1',
#           'closing_price': '92',
#           'max_price': '93',
#           'min_price': '88.2',
#           'opening_price': '88.5',
#           'sell_price': '92.4',
#           'units_traded': '2212933.18477199',
#           'volume_1day': '2212933.18477199',
#           'volume_7day': '26735204.82190442'},
#  'PPT': {'24H_fluctate': '38',
#          '24H_fluctate_rate': '2.86',
#          'average_price': '1337.9509',
#          'buy_price': '1354',
#          'closing_price': '1364',
#          'max_price': '1417',
#          'min_price': '1314',
#          'opening_price': '1326',
#          'sell_price': '1397',
#          'units_traded': '21920.9498',
#          'volume_1day': '21920.9498',
#          'volume_7day': '498604.08947486'},
#  'PST': {'24H_fluctate': '-0.89',
#          '24H_fluctate_rate': '-0.92',
#          'average_price': '97.9358',
#          'buy_price': '96.9',
#          'closing_price': '96.9',
#          'max_price': '101',
#          'min_price': '96',
#          'opening_price': '97.8',
#          'sell_price': '97.6',
#          'units_traded': '422223.5916202',
#          'volume_1day': '422223.5916202',
#          'volume_7day': '9412263.845432666780799255'},
#  'QTUM': {'24H_fluctate': '18',
#           '24H_fluctate_rate': '0.87',
#           'average_price': '2051.5417',
#           'buy_price': '2068',
#           'closing_price': '2072',
#           'max_price': '2106',
#           'min_price': '2003',
#           'opening_price': '2054',
#           'sell_price': '2073',
#           'units_traded': '209599.68486637',
#           'volume_1day': '209599.68486637',
#           'volume_7day': '1077691.47444659'},
#  'RDN': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '1.74',
#          'average_price': '235.3783',
#          'buy_price': '232',
#          'closing_price': '233',
#          'max_price': '249',
#          'min_price': '226',
#          'opening_price': '229',
#          'sell_price': '234',
#          'units_traded': '366481.54592595',
#          'volume_1day': '366481.54592595',
#          'volume_7day': '5598386.84452554506896409'},
#  'REP': {'24H_fluctate': '-90',
#          '24H_fluctate_rate': '-0.68',
#          'average_price': '13212.6106',
#          'buy_price': '12880',
#          'closing_price': '13000',
#          'max_price': '13640',
#          'min_price': '12750',
#          'opening_price': '13090',
#          'sell_price': '13080',
#          'units_traded': '121769.86685978',
#          'volume_1day': '121769.86685978',
#          'volume_7day': '1159958.249216516282980633'},
#  'RNT': {'24H_fluctate': '0.5',
#          '24H_fluctate_rate': '0.68',
#          'average_price': '74.957',
#          'buy_price': '73',
#          'closing_price': '73.1',
#          'max_price': '78.8',
#          'min_price': '71.7',
#          'opening_price': '72.6',
#          'sell_price': '73.2',
#          'units_traded': '6730878.73199256',
#          'volume_1day': '6730878.73199256',
#          'volume_7day': '36041683.327062419770580351'},
#  'ROM': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '12.50',
#          'average_price': '0.0863',
#          'buy_price': '0.08',
#          'closing_price': '0.09',
#          'max_price': '0.09',
#          'min_price': '0.08',
#          'opening_price': '0.08',
#          'sell_price': '0.09',
#          'units_traded': '2632262826.33813333',
#          'volume_1day': '2632262826.33813333',
#          'volume_7day': '11682758966.55980999988888888'},
#  'SALT': {'24H_fluctate': '-2',
#           '24H_fluctate_rate': '-0.84',
#           'average_price': '233.7771',
#           'buy_price': '233',
#           'closing_price': '234',
#           'max_price': '239',
#           'min_price': '228',
#           'opening_price': '236',
#           'sell_price': '236',
#           'units_traded': '117565.562',
#           'volume_1day': '117565.562',
#           'volume_7day': '3499364.42899489'},
#  'SNT': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.47',
#          'average_price': '20.9487',
#          'buy_price': '21',
#          'closing_price': '21',
#          'max_price': '21.6',
#          'min_price': '19.3',
#          'opening_price': '21.1',
#          'sell_price': '21.1',
#          'units_traded': '14829781.60433001',
#          'volume_1day': '14829781.60433001',
#          'volume_7day': '137907933.676882185576157083'},
#  'STEEM': {'24H_fluctate': '10',
#            '24H_fluctate_rate': '3.11',
#            'average_price': '321.7304',
#            'buy_price': '329',
#            'closing_price': '331',
#            'max_price': '331',
#            'min_price': '315',
#            'opening_price': '321',
#            'sell_price': '331',
#            'units_traded': '1185662.2416037',
#            'volume_1day': '1185662.2416037',
#            'volume_7day': '13131878.53490159'},
#  'STRAT': {'24H_fluctate': '23',
#            '24H_fluctate_rate': '2.56',
#            'average_price': '924.8268',
#            'buy_price': '920',
#            'closing_price': '920',
#            'max_price': '973',
#            'min_price': '884',
#            'opening_price': '897',
#            'sell_price': '930',
#            'units_traded': '234164.19704745',
#            'volume_1day': '234164.19704745',
#            'volume_7day': '1044930.47919413'},
#  'THETA': {'24H_fluctate': '-0.09',
#            '24H_fluctate_rate': '-0.17',
#            'average_price': '57.7132',
#            'buy_price': '57.5',
#            'closing_price': '57.7',
#            'max_price': '59.9',
#            'min_price': '56',
#            'opening_price': '57.8',
#            'sell_price': '57.7',
#            'units_traded': '3215166.49276527',
#            'volume_1day': '3215166.49276527',
#            'volume_7day': '135655884.57225318825980803'},
#  'TMTG': {'24H_fluctate': '0.13',
#           '24H_fluctate_rate': '3.53',
#           'average_price': '3.7491',
#           'buy_price': '3.8',
#           'closing_price': '3.81',
#           'max_price': '3.88',
#           'min_price': '3.63',
#           'opening_price': '3.68',
#           'sell_price': '3.81',
#           'units_traded': '225154208.2466298',
#           'volume_1day': '225154208.2466298',
#           'volume_7day': '1830906101.76036308798481357'},
#  'TRUE': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '237',
#           'buy_price': '237',
#           'closing_price': '237',
#           'max_price': '243',
#           'min_price': '230',
#           'opening_price': '237',
#           'sell_price': '240',
#           'units_traded': '139665.9877',
#           'volume_1day': '139665.9877',
#           'volume_7day': '1752841.306428858105742296'},
#  'TRX': {'24H_fluctate': '-0.3',
#          '24H_fluctate_rate': '-0.99',
#          'average_price': '30.412',
#          'buy_price': '29.9',
#          'closing_price': '30',
#          'max_price': '31',
#          'min_price': '29.6',
#          'opening_price': '30.3',
#          'sell_price': '30',
#          'units_traded': '996528131.76666546',
#          'volume_1day': '996528131.76666546',
#          'volume_7day': '5913144188.8712669'},
#  'VET': {'24H_fluctate': '0.12',
#          '24H_fluctate_rate': '2.77',
#          'average_price': '4.4149',
#          'buy_price': '4.41',
#          'closing_price': '4.44',
#          'max_price': '4.54',
#          'min_price': '4.26',
#          'opening_price': '4.32',
#          'sell_price': '4.44',
#          'units_traded': '104268934.08507541',
#          'volume_1day': '104268934.08507541',
#          'volume_7day': '704617301.588704972930029874'},
#  'WAVES': {'24H_fluctate': '52',
#            '24H_fluctate_rate': '1.62',
#            'average_price': '3244.5446',
#            'buy_price': '3215',
#            'closing_price': '3259',
#            'max_price': '3394',
#            'min_price': '3033',
#            'opening_price': '3207',
#            'sell_price': '3259',
#            'units_traded': '225410.73267326',
#            'volume_1day': '225410.73267326',
#            'volume_7day': '2348641.45688067'},
#  'WAX': {'24H_fluctate': '1.2',
#          '24H_fluctate_rate': '3.31',
#          'average_price': '36.9054',
#          'buy_price': '36.8',
#          'closing_price': '37.4',
#          'max_price': '37.5',
#          'min_price': '35.4',
#          'opening_price': '36.2',
#          'sell_price': '37.3',
#          'units_traded': '2225561.66559465',
#          'volume_1day': '2225561.66559465',
#          'volume_7day': '20476714.72210359'},
#  'WET': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '2.67',
#          'average_price': '11.4899',
#          'buy_price': '11.5',
#          'closing_price': '11.5',
#          'max_price': '11.7',
#          'min_price': '11.2',
#          'opening_price': '11.2',
#          'sell_price': '11.6',
#          'units_traded': '16488187.20523473',
#          'volume_1day': '16488187.20523473',
#          'volume_7day': '129100692.30638786893892444'},
#  'WTC': {'24H_fluctate': '-17',
#          '24H_fluctate_rate': '-1.52',
#          'average_price': '1097.5608',
#          'buy_price': '1093',
#          'closing_price': '1101',
#          'max_price': '1119',
#          'min_price': '1070',
#          'opening_price': '1118',
#          'sell_price': '1104',
#          'units_traded': '17742.2934',
#          'volume_1day': '17742.2934',
#          'volume_7day': '458109.09701063014715693'},
#  'XEM': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '0.38',
#          'average_price': '52.6569',
#          'buy_price': '52.4',
#          'closing_price': '52.5',
#          'max_price': '53.6',
#          'min_price': '51.4',
#          'opening_price': '52.3',
#          'sell_price': '53.4',
#          'units_traded': '1290679.13325829',
#          'volume_1day': '1290679.13325829',
#          'volume_7day': '6132911.61353082'},
#  'XLM': {'24H_fluctate': '2.6',
#          '24H_fluctate_rate': '2.80',
#          'average_price': '93.4092',
#          'buy_price': '95.2',
#          'closing_price': '95.2',
#          'max_price': '98',
#          'min_price': '90.1',
#          'opening_price': '92.6',
#          'sell_price': '95.6',
#          'units_traded': '19108639.13265591',
#          'volume_1day': '19108639.13265591',
#          'volume_7day': '97973618.58454733'},
#  'XMR': {'24H_fluctate': '80',
#          '24H_fluctate_rate': '0.16',
#          'average_price': '48140.8471',
#          'buy_price': '48480',
#          'closing_price': '48490',
#          'max_price': '49280',
#          'min_price': '47300',
#          'opening_price': '48410',
#          'sell_price': '48580',
#          'units_traded': '13234560.38293151',
#          'volume_1day': '13234560.38293151',
#          'volume_7day': '38821580.652200191319'},
#  'XRP': {'24H_fluctate': '30',
#          '24H_fluctate_rate': '9.31',
#          'average_price': '340.7903',
#          'buy_price': '351',
#          'closing_price': '352',
#          'max_price': '359',
#          'min_price': '317',
#          'opening_price': '322',
#          'sell_price': '352',
#          'units_traded': '92173256.86897271',
#          'volume_1day': '92173256.86897271',
#          'volume_7day': '263285345.76811686'},
#  'XVG': {'24H_fluctate': '0.09',
#          '24H_fluctate_rate': '1.33',
#          'average_price': '6.7664',
#          'buy_price': '6.78',
#          'closing_price': '6.83',
#          'max_price': '6.95',
#          'min_price': '6.59',
#          'opening_price': '6.74',
#          'sell_price': '6.84',
#          'units_traded': '3456494.69576414',
#          'volume_1day': '3456494.69576414',
#          'volume_7day': '71170189.99106544'},
#  'ZEC': {'24H_fluctate': '400',
#          '24H_fluctate_rate': '0.74',
#          'average_price': '54376.3136',
#          'buy_price': '54350',
#          'closing_price': '54450',
#          'max_price': '55450',
#          'min_price': '53400',
#          'opening_price': '54050',
#          'sell_price': '54450',
#          'units_traded': '530337.54429266',
#          'volume_1day': '530337.54429266',
#          'volume_7day': '50690263.971052'},
#  'ZIL': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.44',
#          'average_price': '22.5836',
#          'buy_price': '22.5',
#          'closing_price': '22.6',
#          'max_price': '23.1',
#          'min_price': '22',
#          'opening_price': '22.5',
#          'sell_price': '22.6',
#          'units_traded': '49187437.85281324',
#          'volume_1day': '49187437.85281324',
#          'volume_7day': '424272498.022332654356'},
#  'ZRX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.35',
#          'average_price': '281.385',
#          'buy_price': '283',
#          'closing_price': '283',
#          'max_price': '287',
#          'min_price': '275',
#          'opening_price': '282',
#          'sell_price': '284',
#          'units_traded': '320055.24184874',
#          'volume_1day': '320055.24184874',
#          'volume_7day': '5322597.751418180757916792'},
#  'date': '1548871050356'}

# %%
# 아래에 코드를 작성하세요.
for key, value in currency.items():
    if type(value) == type(dict()):
        gap = float(btc['opening_price'])+(float(btc['max_price'])-float(btc['min_price']))
        if gap > float(btc['max_price']):
            print(f'{key:5}상승장')
        else:
            print(f'{key:5}하락장')
# Out:
# BTC  상승장
# ETH  상승장
# DASH 상승장
# LTC  상승장
# ETC  상승장
# XRP  상승장
# BCH  상승장
# XMR  상승장
# ZEC  상승장
# QTUM 상승장
# BTG  상승장
# EOS  상승장
# ICX  상승장
# VET  상승장
# TRX  상승장
# ELF  상승장
# MITH 상승장
# MCO  상승장
# OMG  상승장
# KNC  상승장
# GNT  상승장
# ZIL  상승장
# ETHOS상승장
# PAY  상승장
# WAX  상승장
# POWR 상승장
# LRC  상승장
# GTO  상승장
# STEEM상승장
# STRAT상승장
# ZRX  상승장
# REP  상승장
# AE   상승장
# XEM  상승장
# SNT  상승장
# ADA  상승장
# PPT  상승장
# CTXC 상승장
# CMT  상승장
# THETA상승장
# WTC  상승장
# ITC  상승장
# TRUE 상승장
# ABT  상승장
# RNT  상승장
# PLY  상승장
# WAVES상승장
# LINK 상승장
# ENJ  상승장
# PST  상승장
# SALT 상승장
# RDN  상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS  상승장
# BCD  상승장
# BZNT 상승장
# XLM  상승장
# OCN  상승장
# BSV  상승장
# TMTG 상승장
# BAT  상승장
# WET  상승장
# XVG  상승장
# IOST 상승장
# POLY 상승장
# HC   상승장
# ROM  상승장
# AMO  상승장
# ETZ  상승장
# ARN  상승장
# APIS 상승장
# MTL  상승장
