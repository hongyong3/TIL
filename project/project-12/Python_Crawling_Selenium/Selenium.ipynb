# %%
# 자동화 테스트를 위해 셀레니움(Selenium)을 불러옵니다
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup

# 크롬 웹 드라이버의 경로를 설정합니다.
driver =  webdriver.Chrome('C:\Chrome_Driver\chromedriver.exe')
# 크롬을 통해 네이버 로그인 화면에 접속합니다.
# driver.get('https://google.com')
driver.get('https://nid.naver.com/nidlogin.login')

# 아이디와 비밀번호를 입력합니다. (0.5초씩 기다리기)
sleep(1)
driver.find_element_by_name('id').send_keys('아이디')
sleep(1)
driver.find_element_by_name('pw').send_keys('비밀번호')

# Xpath를 이용해 로그인을 시도합니다.
driver.find_element_by_xpath('//*[@id="frmNIDLogin"]/fieldset/input').click()

# 웹 페이지의 소스코드를 파싱하기 위해 Beautiful Soup 라이브러리를 불러옵니다.

driver.get("https://mail.naver.com/")
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# 메일 제목을 하나씩 파싱합니다.
title_list = soup.find_all('strong', 'mail_title')

for title in title_list:
    print(title.text)

# %%
# 아이디와 비밀번호를 입력합니다. (0.5초씩 기다리기)
sleep(0.5)
driver.find_element_by_name('id').send_keys('아이디')
sleep(0.5)
driver.find_element_by_name('pw').send_keys('비밀번호')

# %%
# Xpath를 이용해 로그인을 시도합니다.
driver.find_element_by_xpath('//*[@id="frmNIDLogin"]/fieldset/input').click()

# %%
# 웹 페이지의 소스코드를 파싱하기 위해 Beautiful Soup 라이브러리를 불러옵니다.
from bs4 import BeautifulSoup

driver.get("https://mail.naver.com/")
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# 메일 제목을 하나씩 파싱합니다.
title_list = soup.find_all('strong', 'mail_title')

for title in title_list:
    print(title.text)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-cb3d8864244a> in <module>
#       2 from bs4 import BeautifulSoup
#       3
# ----> 4 driver.get("https://mail.naver.com/")
#       5 html = driver.page_source
#       6 soup = BeautifulSoup(html, 'lxml')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
# ...

# %%
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup

# 크롬 웹 드라이버의 경로를 설정.
driver =  webdriver.Chrome('C:\Chrome_Driver\chromedriver.exe')
# 크롬을 통해 구글 화면에 접속.
driver.get('https://google.com')
search_box = driver.find_element_by_name("q")
search_box.send_keys("네이버영화")
sleep(0.5)
search_box.submit()
sleep(0.5)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
 
url = urlopen("https://movie.naver.com/movie/running/current.nhn")
bs = BeautifulSoup(url, 'html.parser')
body = bs.body
 
target = body.find(class_="lst_detail_t1")
list = target.find_all('li')
no = 1
for n in range(0, len(list)) :
    print("=================================")
    print("No.",no)
    no += 1
    
    # 영화 제목
    title = list[n].find(class_="tit").find("a").text
    print("영화 제목 :\t", title)
    
    # 장르
    try:
        genre = list[n].find(class_="info_txt1").find_all("dd")[0].find("span").find_all("a")
        genreList = [genre.text.strip() for genre in genre]
        print("장르 :\t", genreList)
    except IndexError:
        print("장르 :\t 정보 없음")
 
    # 감독
    try:
        director = list[n].find(class_="info_txt1").find_all("dd")[1].find("span").find_all("a")
        directorList = [director.text.strip() for director in director]
        print("제작 감독 :\t", directorList)
    except IndexError:
        print("제작 감독 :\t 정보 없음")
        
    # 출연 배우
    try:
        cast = list[n].find(class_="lst_dsc").find("dl", class_="info_txt1").find_all("dd")[2].find(class_="link_txt").find_all("a")
        castList = [cast.text.strip() for cast in cast]
        print("출연 배우 :\t", castList)
    except IndexError:
        print("출연 배우 :\t 정보 없음")
        
    # 포스터
    try:
        posterUrl = list[n].find(class_="thumb").find("a").find("img")
        print("포스터 :\t", posterUrl)
    except IndexError:
        print("포스터 : \t 정보 없음")
    
    # 평점
    try:
        star = list[n].find(class_="lst_dsc").find_all("dd")[0].find_all("dl")[0].find("dd").find("div").find("a").find_all("span")[2].text
        starPeople = list[n].find(class_="lst_dsc").find_all("dd")[0].find_all("dl")[0].find("dd").find("div").find("a").find_all("span")[3].text
        print("평점 :\t", starPeople, "->", star)
    except IndexError:
        print("평점 :\t 정보 없음")
    
    # 개봉연도
#     try:
#         release = list[n].find(class_="lst_wrap").find("ul")
#         .find("li").find("dl").find_all("dd")[1].find("dl").find_all("dd")[0]
#         releaseList = [release.text.strip() for release in release]
#         print("개봉연도 :\t", release)
#     except IndexError:
#         print("개봉연도 :\t 정보 없음")
        
    # 상영시간
    
    #
# Out:
# ...
# No. 1
# 영화 제목 :	 어벤져스: 엔드게임
# 장르 :	 ['액션', 'SF']
# 제작 감독 :	 ['안소니 루소', '조 루소']
# 출연 배우 :	 ['로버트 다우니 주니어', '크리스 에반스', '크리스 헴스워스', '마크 러팔로', '스칼렛 요한슨', '제레미 레너', '폴 러드', '돈 치들', '브리 라슨', '카렌 길런', '브래들리 쿠퍼', '조슈 브롤린']
# 포스터 :	 <img alt="어벤져스: 엔드게임" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20190417_250/1555465284425i6WQE_JPEG/movie_image.jpg?type=m99_141_2"/>
# 평점 :	 참여 61,710명 -> 9.41
# ...
# No. 2
# 영화 제목 :	 걸캅스
# 장르 :	 ['코미디', '액션']
# 제작 감독 :	 ['정다원']
# 출연 배우 :	 ['라미란', '이성경']
# 포스터 :	 <img alt="걸캅스" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20190418_272/155557683107045leS_JPEG/movie_image.jpg?type=m99_141_2"/>
# 평점 :	 참여 25,942명 -> 5.64
# ...
# No. 3
# 영화 제목 :	 나의 특별한 형제
# 장르 :	 ['드라마', '코미디']
# 제작 감독 :	 ['육상효']
# 출연 배우 :	 ['신하균', '이광수', '이솜']
# ...

# %%
import requests
import http.client
from bs4 import BeautifulSoup

url = "https://api.themoviedb.org/3/movie/now-playing"

payload = "{}"
response = requests.request("GET", url, data=payload)
conn = http.client.HTTPSConnection("api.themoviedb.org")
conn.request("GET", "/3/movie/upcoming?language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)

res = conn.getresponse()
data = res.read()
print(response.text)
print(data.decode("utf-8"))
# Out:
# {"status_code":7,"status_message":"Invalid API key: You must be granted a valid key."}
# ...

# %%
import http.client
from bs4 import BeautifulSoup

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"
conn.request("GET", "/3/movie/now_playing?page=1&language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"results":[{"vote_count":4845,"id":299534,"video":false,"vote_average":8.6,"title":"어벤져스: 엔드게임","popularity":303.658,"poster_path":"\/n78LK2t1uQP68Ud0VXHRe0HmKOp.jpg","original_language":"en","original_title":"Avengers: Endgame","genre_ids":[12,878,28],"backdrop_path":"\/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg","adult":false,"overview":"인피니티 워 이후 절반만 살아남은 지구, 마지막 희망이 된 어벤져스! 먼저 떠난 그들을 위해 모든 것을 걸었다!","release_date":"2019-04-24"},{"vote_count":333,"id":456740,"video":false,"vote_average":5.1,"title":"헬보이","popularity":184.343,"poster_path":"\/gua7L4syuPUZeG35lpu5xvOzquH.jpg","original_language":"en","original_title":"Hellboy","genre_ids":[28,12,14],"backdrop_path":"\/5BkSkNtfrnTuKOtTaZhl8avn4wU.jpg","adult":false,"overview":"'헬보이' 자신이 소속된 B.P.R.D의 임무로 영국의 한 비밀 단체의 괴수 사냥을 도우러 갔지만 되려 공격을 당하고, 곧 영국에서 어마어마한 일이 벌어지고 있다는 것을 알게 된다. 서기 566년, 아서왕에게 패하고 몸이 7조각으로 나뉘어 봉인된 '블러드 퀸'을 다시 부활시켜 인류를 파멸시키려는 초자연적 빌런들에 의해 영국은 물론 전 세계가 위험에 빠지게 된다. 헬보이는 이들에 맞서 인류를 위험으로부터 구해야만 하는데…","release_date":"2019-04-10"},{"vot
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/movie/now_playing?page=1~11&language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"results":[{"vote_count":4845,"id":299534,"video":false,"vote_average":8.6,"title":"어벤져스: 엔드게임","popularity":303.658,"poster_path":"\/n78LK2t1uQP68Ud0VXHRe0HmKOp.jpg","original_language":"en","original_title":"Avengers: Endgame","genre_ids":[12,878,28],"backdrop_path":"\/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg","adult":false,"overview":"인피니티 워 이후 절반만 살아남은 지구, 마지막 희망이 된 어벤져스! 먼저 떠난 그들을 위해 모든 것을 걸었다!","release_date":"2019-04-24"},{"vote_count":333,"id":456740,"video":false,"vote_average":5.1,"title":"헬보이","popularity":184.343,"poster_path":"\/gua7L4syuPUZeG35lpu5xvOzquH.jpg","original_language":"en","original_title":"Hellboy","genre_ids":[28,12,14],"backdrop_path":"\/5BkSkNtfrnTuKOtTaZhl8avn4wU.jpg","adult":false,"overview":"'헬보이' 자신이 소속된 B.P.R.D의 임무로 영국의 한 비밀 단체의 괴수 사냥을 도우러 갔지만 되려 공격을 당하고, 곧 영국에서 어마어마한 일이 벌어지고 있다는 것을 알게 된다. 서기 566년, 아서왕에게 패하고 몸이 7조각으로 나뉘어 봉인된 '블러드 퀸'을 다시 부활시켜 인류를 파멸시키려는 초자연적 빌런들에 의해 영국은 물론 전 세계가 위험에 빠지게 된다. 헬보이는 이들에 맞서 인류를 위험으로부터 구해야만 하는데…","release_date":"2019-04-10"},{"vot
# ...

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"
conn.request("GET", "/3/movie/now_playing?page={2}&language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)
res = conn.getresponse()
data = res.read()
datas = data.json
print(data.decode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-c77c2fc2f351> in <module>
#       8 res = conn.getresponse()
#       9 data = res.read()
# ---> 10 datas = data.json
#      11 print(data.decode("utf-8"))
#
# AttributeError: 'bytes' object has no attribute 'json'

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"
for page in range(1, 11):
    conn("/3/movie/now_playing?page=", page, "&language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)
    res = conn.getresponse()
    data = res.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-69f27cadf2f8> in <module>
#       6 payload = "{}"
#       7 for page in range(1, 11):
# ----> 8     conn("/3/movie/now_playing?page=", page, "&language=ko-kr&api_key=f55decdd8b4533ff751d5e5df47ac372", payload)
#       9     res = conn.getresponse()
#      10     data = res.read()
#
# TypeError: 'HTTPSConnection' object is not callable
